# %%
# 使下面的代码支持python2和python3
from __future__ import division, print_function, unicode_literals

# 查看python的版本是否为3.5及以上
import sys
assert sys.version_info >= (3, 5)

# 查看sklearn的版本是否为0.20及以上
import sklearn
assert sklearn.__version__ >= "0.20"

import numpy as np
import pandas as pd
import os 

# 在每一次的运行后获得的结果与这个notebook的结果相同
np.random.seed(42) 

# 让matplotlib的图效果更好
# %matplotlib inline
import matplotlib as mpl
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# 设置保存图片的途径
PROJECT_ROOT_DIR = "."
IMAGE_PATH = os.path.join(PROJECT_ROOT_DIR, "images")
os.makedirs(IMAGE_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True):
    '''
    只需在fe_ml_3rd.ipynb文件所在目录处，建立一个images的文件夹，运行即可保存自动图片
    
    fig_id : 图片名称
    '''
    path = os.path.join(PROJECT_ROOT_DIR, "images", fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)
    
# 忽略掉没用的警告 (Scipy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %%
df = pd.read_excel("总数据7.13修改版.xlsx")

# %%
df
# Out:
#                                            Sample type  天然：1   SiO2  TiO2  \
# 0    hedenbergite (CaFeSi2O6)–petedunnite (CaZnSi2O...   2.0  48.09   NaN
# 1    hedenbergite (CaFeSi2O6)–petedunnite (CaZnSi2O...   2.0  48.18   NaN
# 2    hedenbergite (CaFeSi2O6)–petedunnite (CaZnSi2O...   2.0  48.41   NaN
# 3    hedenbergite (CaFeSi2O6)–petedunnite (CaZnSi2O...   2.0  47.37   NaN
# 4    hedenbergite (CaFeSi2O6)–petedunnite (CaZnSi2O...   2.0  47.47   NaN
# ..                                                 ...   ...    ...   ...
# 385                                          AL-augite   1.0  48.72  1.72
# 386                                        ureyite（均值）   1.0  54.81  0.03
# 387                                           aegirine   1.0  52.41  0.59
# 388                                           aegirine   1.0  51.22  0.96
# 389                                           aegirine   1.0  50.91  0.45
#
#      Al2O3  Cr2O3  FeOtot   MnO    MgO    CaO   Na2O   K2O  P2O5  NiO    ZnO  \
# 0      NaN    NaN   29.61   NaN    NaN  21.60    NaN   NaN   NaN  NaN    NaN
# 1      NaN    NaN   29.17   NaN    NaN  22.95    NaN   NaN   NaN  NaN    NaN
# 2      NaN    NaN   24.42   NaN    NaN  22.53    NaN   NaN   NaN  NaN   5.16
# 3      NaN    NaN   22.81   NaN    NaN  22.12    NaN   NaN   NaN  NaN   7.61
# 4      NaN    NaN   18.96   NaN    NaN  22.49    NaN   NaN   NaN  NaN  10.81
# ..     ...    ...     ...   ...    ...    ...    ...   ...   ...  ...    ...
# 385   9.61   0.02    7.43  0.14  12.86  19.36   0.99   NaN   NaN  NaN    NaN
# 386   4.02  23.67    3.61  0.02   0.49   0.54  12.94  0.02  0.09  NaN    NaN
# 387   1.04    NaN   30.95  0.93   0.33   3.03  11.87   NaN   NaN  NaN    NaN
# 388   2.16    NaN   28.85  0.71   0.14   0.44  12.98   NaN   NaN  NaN    NaN
# 389   1.14    NaN   30.14  0.90   0.46   4.48  10.59   NaN   NaN  NaN    NaN
#
#      Li2O  ZrO2  V2O5  Fe3+/Fetot
# 0     NaN   NaN   NaN       0.000
# 1     NaN   NaN   NaN       0.000
# 2     NaN   NaN   NaN       0.000
# 3     NaN   NaN   NaN       0.000
# 4     NaN   NaN   NaN       0.106
# ..    ...   ...   ...         ...
# 385   NaN   NaN   NaN       0.330
# 386   NaN   NaN   NaN       1.000
# 387   NaN  1.07   NaN       0.884
# 388   NaN  0.43   NaN       0.884
# 389   NaN  0.42   NaN       0.778
#
# [390 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['Sample type', '天然：1', 'SiO2', 'TiO2', 'Al2O3', 'Cr2O3', 'FeOtot',
#        'MnO', 'MgO', 'CaO', 'Na2O', 'K2O', 'P2O5', 'NiO', 'ZnO', 'Li2O',
#        'ZrO2', 'V2O5', 'Fe3+/Fetot'],
#       dtype='object')

# %%
# 建立副本，以免修改原数据
df_edit = df.iloc[:, 2:]

# %%
df_edit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 17 columns):
# SiO2          390 non-null float64
# TiO2          354 non-null float64
# Al2O3         364 non-null float64
# Cr2O3         348 non-null float64
# FeOtot        390 non-null float64
# MnO           330 non-null float64
# MgO           379 non-null float64
# CaO           390 non-null float64
# Na2O          380 non-null float64
# K2O           169 non-null float64
# P2O5          5 non-null float64
# NiO           171 non-null float64
# ZnO           15 non-null float64
# Li2O          5 non-null float64
# ZrO2          3 non-null float64
# V2O5          8 non-null float64
# Fe3+/Fetot    390 non-null float64
# dtypes: float64(17)
# memory usage: 51.9 KB

# %%
df_edit.describe()
# Out:
#              SiO2        TiO2         Al2O3       Cr2O3      FeOtot  \
# count  390.000000  354.000000  3.640000e+02  348.000000  390.000000
# mean    52.588121    0.683474  5.634114e+00    0.804728    5.821023
# std      3.169816    1.334923  4.238189e+00    1.418578    7.056935
# min     41.620000    0.000000  1.000000e-07    0.000000    0.040000
# 25%     51.220000    0.090000  2.460000e+00    0.070000    2.542500
# 50%     52.415000    0.340000  5.795000e+00    0.710000    3.295000
# 75%     54.777500    0.630000  7.102500e+00    1.160000    6.662500
# max     64.960000    9.760000  2.821600e+01   23.670000   54.350000
#
#               MnO           MgO           CaO        Na2O           K2O  \
# count  330.000000  3.790000e+02  3.900000e+02  380.000000  1.690000e+02
# mean     0.112056  1.436257e+01  1.817262e+01    2.171707  3.023375e-02
# std      0.130789  4.487865e+00  5.577510e+00    2.221430  7.362901e-02
# min      0.000000  1.000000e-07  1.000000e-07    0.000000  0.000000e+00
# 25%      0.040000  1.246000e+01  1.780750e+01    1.000000  1.000000e-07
# 50%      0.090000  1.510000e+01  1.980000e+01    1.570000  5.000000e-03
# 75%      0.120000  1.637000e+01  2.107250e+01    2.112500  3.000000e-02
# max      0.930000  3.975000e+01  2.550000e+01   12.980000  6.300000e-01
#
#            P2O5         NiO           ZnO      Li2O      ZrO2          V2O5  \
# count  5.000000  171.000000  1.500000e+01  5.000000  3.000000  8.000000e+00
# mean   0.205200    0.050912  7.260000e+00  7.684000  0.640000  4.200004e-02
# std    0.321835    0.070330  9.673504e+00  0.122558  0.372424  3.600392e-02
# min    0.040000    0.000000  1.000000e-07  7.500000  0.420000  1.000000e-07
# 25%    0.055000    0.020000  1.000000e-07  7.621000  0.425000  1.000000e-07
# 50%    0.061000    0.040000  1.000000e-07  7.739000  0.430000  5.650000e-02
# 75%    0.090000    0.060000  1.292500e+01  7.760000  0.750000  6.925000e-02
# max    0.780000    0.470000  2.690000e+01  7.800000  1.070000  8.400000e-02
#
#        Fe3+/Fetot
# count  390.000000
# mean     0.277177
# std      0.214405
# min      0.000000
# 25%      0.154775
# 50%      0.230000
# 75%      0.320000
# max      1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# 用柱状图的方式表示出来，横坐标为含量，纵坐标为数量
df_edit.hist(bins=50, figsize=(20, 15))
save_fig('data_describe')
plt.show()
# Out:
# Saving figure data_describe

# %%
# 查找每对属性间的皮尔逊相关系数，即相关系数矩阵
corr_matrix = df_edit.corr()

# %%
corr_matrix
# Out:
#                 SiO2      TiO2     Al2O3     Cr2O3    FeOtot       MnO  \
# SiO2        1.000000 -0.147970  0.086674  0.084975 -0.373479 -0.278171
# TiO2       -0.147970  1.000000 -0.056922 -0.152735 -0.040777 -0.007273
# Al2O3       0.086674 -0.056922  1.000000 -0.067491 -0.219126 -0.088014
# Cr2O3       0.084975 -0.152735 -0.067491  1.000000 -0.185514 -0.060642
# FeOtot     -0.373479 -0.040777 -0.219126 -0.185514  1.000000  0.344348
# MnO        -0.278171 -0.007273 -0.088014 -0.060642  0.344348  1.000000
# MgO         0.053447 -0.139259 -0.416861  0.008497 -0.358755 -0.183629
# CaO        -0.298423  0.128355 -0.281077 -0.069348 -0.475406 -0.043607
# Na2O        0.346860 -0.009840  0.262907  0.173983  0.023268 -0.045479
# K2O         0.041493 -0.057670 -0.039198 -0.045668  0.080445 -0.025438
# P2O5       -0.547651 -0.188904 -0.416450       NaN  0.506131  0.618937
# NiO         0.101765 -0.152378 -0.007463  0.029392 -0.133151 -0.152764
# ZnO        -0.901960       NaN       NaN       NaN  0.348216       NaN
# Li2O        0.387234  0.252945 -0.017285       NaN  0.004801 -0.245729
# ZrO2        0.983195 -0.238957 -0.557137       NaN  0.784918  0.594172
# V2O5        0.291250  0.151551 -0.733644  0.847341 -0.438791  0.286214
# Fe3+/Fetot  0.277212  0.105109  0.398238  0.136139 -0.060955  0.088149
#
#                  MgO       CaO      Na2O       K2O      P2O5       NiO  \
# SiO2        0.053447 -0.298423  0.346860  0.041493 -0.547651  0.101765
# TiO2       -0.139259  0.128355 -0.009840 -0.057670 -0.188904 -0.152378
# Al2O3      -0.416861 -0.281077  0.262907 -0.039198 -0.416450 -0.007463
# Cr2O3       0.008497 -0.069348  0.173983 -0.045668       NaN  0.029392
# FeOtot     -0.358755 -0.475406  0.023268  0.080445  0.506131 -0.133151
# MnO        -0.183629 -0.043607 -0.045479 -0.025438  0.618937 -0.152764
# MgO         1.000000  0.189288 -0.586601 -0.051134  0.375507  0.145662
# CaO         0.189288  1.000000 -0.354904 -0.023971  0.576144 -0.015756
# Na2O       -0.586601 -0.354904  1.000000  0.052979 -0.149329 -0.019380
# K2O        -0.051134 -0.023971  0.052979  1.000000  0.959983  0.254495
# P2O5        0.375507  0.576144 -0.149329  0.959983  1.000000       NaN
# NiO         0.145662 -0.015756 -0.019380  0.254495       NaN  1.000000
# ZnO              NaN  0.526712       NaN       NaN       NaN       NaN
# Li2O        0.602549  0.224392  0.042606  0.240925  1.000000       NaN
# ZrO2        0.094267  0.147530  0.054443       NaN       NaN       NaN
# V2O5        0.411657  0.074784 -0.672321       NaN       NaN  0.011223
# Fe3+/Fetot -0.423090 -0.195911  0.443645 -0.133499 -0.564129  0.132259
#
#                  ZnO      Li2O      ZrO2      V2O5  Fe3+/Fetot
# SiO2       -0.901960  0.387234  0.983195  0.291250    0.277212
# TiO2             NaN  0.252945 -0.238957  0.151551    0.105109
# Al2O3            NaN -0.017285 -0.557137 -0.733644    0.398238
# Cr2O3            NaN       NaN       NaN  0.847341    0.136139
# FeOtot      0.348216  0.004801  0.784918 -0.438791   -0.060955
# MnO              NaN -0.245729  0.594172  0.286214    0.088149
# MgO              NaN  0.602549  0.094267  0.411657   -0.423090
# CaO         0.526712  0.224392  0.147530  0.074784   -0.195911
# Na2O             NaN  0.042606  0.054443 -0.672321    0.443645
# K2O              NaN  0.240925       NaN       NaN   -0.133499
# P2O5             NaN  1.000000       NaN       NaN   -0.564129
# NiO              NaN       NaN       NaN  0.011223    0.132259
# ZnO         1.000000       NaN       NaN       NaN   -0.634439
# Li2O             NaN  1.000000       NaN       NaN    0.220511
# ZrO2             NaN       NaN  1.000000       NaN    0.511582
# V2O5             NaN       NaN       NaN  1.000000   -0.393636
# Fe3+/Fetot -0.634439  0.220511  0.511582 -0.393636    1.000000

# %%
# 查看每个属性和目标值的相关系数（只测量线性关系），接近1表示强正相关，接近-1表示强负相关，接近0表示没有线性关系
corr_matrix["Fe3+/Fetot"].sort_values(ascending=False)
# Out:
# Fe3+/Fetot    1.000000
# ZrO2          0.511582
# Na2O          0.443645
# Al2O3         0.398238
# SiO2          0.277212
# Li2O          0.220511
# Cr2O3         0.136139
# NiO           0.132259
# TiO2          0.105109
# MnO           0.088149
# FeOtot       -0.060955
# K2O          -0.133499
# CaO          -0.195911
# V2O5         -0.393636
# MgO          -0.423090
# P2O5         -0.564129
# ZnO          -0.634439
# Name: Fe3+/Fetot, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# 查看前四个相关系数最大的属性的分布
attributes = ['Fe3+/Fetot', 'Al2O3', 'SiO2', 'TiO2']
scatter_matrix(df_edit[attributes], figsize=(12, 8))
save_fig('corr_four')
# Out:
# Saving figure corr_four

# %%
from sklearn.model_selection import train_test_split

# 划分训练集和测试集
train_set, test_set = train_test_split(df_edit, test_size=0.2, random_state=42)
# drop()会创建一份数据备份，不会影响train_set，major_el为特征值，major_el_labels为标签值
major_el = train_set.drop("Fe3+/Fetot", axis=1)
major_el_labels = train_set["Fe3+/Fetot"].copy()
major_el_test = test_set.drop("Fe3+/Fetot", axis=1)
major_el_test_labels = test_set["Fe3+/Fetot"].copy()

# %%
major_el.shape
# Out:
# (312, 16)

# %%
major_el_test.shape
# Out:
# (78, 16)

# %%
# 查看哪一列含空值
major_el.isnull().any(axis=0)
# Out:
# SiO2      False
# TiO2       True
# Al2O3      True
# Cr2O3      True
# FeOtot    False
# MnO        True
# MgO        True
# CaO       False
# Na2O       True
# K2O        True
# P2O5       True
# NiO        True
# ZnO        True
# Li2O       True
# ZrO2       True
# V2O5       True
# dtype: bool

# %%
# 将训练集中特征的空值插值为0
major_el.fillna(0, inplace=True)
major_el
# Out:
#       SiO2  TiO2  Al2O3  Cr2O3  FeOtot   MnO    MgO    CaO  Na2O  \
# 291  51.71  0.80   7.16   0.62    2.97  0.68  14.72  19.91  2.20
# 63   51.22  0.47   6.35   0.70    3.09  0.08  15.00  20.29  1.43
# 239  51.97  0.30   3.12   0.17    7.26  0.15  16.84  20.74  0.20
# 353  54.10  0.22   2.94   1.24    2.49  0.00  17.00  19.70  1.99
# 219  51.59  0.24   6.92   0.82    2.58  0.12  15.27  20.99  1.25
# ..     ...   ...    ...    ...     ...   ...    ...    ...   ...
# 71   52.27  0.51   5.97   0.98    2.86  0.10  15.68  19.76  1.65
# 106  47.13  2.48   6.67   0.08    7.55  0.15  12.36  22.49  0.66
# 270  51.18  0.64   6.62   0.93    2.67  0.09  14.75  21.09  1.81
# 348  55.10  0.11   2.42   1.78    2.05  0.00  17.30  19.20  1.87
# 102  50.06  0.00   8.21   0.00    7.91  0.06  15.34  15.71  1.97
#
#               K2O  P2O5   NiO           ZnO  Li2O  ZrO2  V2O5
# 291  0.000000e+00   0.0  0.06  0.000000e+00   0.0   0.0  0.00
# 63   0.000000e+00   0.0  0.02  0.000000e+00   0.0   0.0  0.00
# 239  0.000000e+00   0.0  0.00  0.000000e+00   0.0   0.0  0.00
# 353  1.000000e-07   0.0  0.00  0.000000e+00   0.0   0.0  0.00
# 219  0.000000e+00   0.0  0.04  0.000000e+00   0.0   0.0  0.00
# ..            ...   ...   ...           ...   ...   ...   ...
# 71   0.000000e+00   0.0  0.03  0.000000e+00   0.0   0.0  0.00
# 106  0.000000e+00   0.0  0.00  0.000000e+00   0.0   0.0  0.00
# 270  1.000000e-07   0.0  0.10  1.000000e-07   0.0   0.0  0.07
# 348  1.000000e-07   0.0  0.00  0.000000e+00   0.0   0.0  0.00
# 102  1.000000e-02   0.0  0.00  0.000000e+00   0.0   0.0  0.00
#
# [312 rows x 16 columns]

# %%
test = train_set.drop("Fe3+/Fetot", axis=1)
a1= test.shape[0]
print(a1)
# Out:
# 312

# %%
test2 = test_set.drop("Fe3+/Fetot", axis=1)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

impute = SimpleImputer(strategy="mean")
test_processed = impute.fit_transform(major_el)
print(test_processed.shape)
test2_processed = impute.transform(major_el_test)
print(test2_processed.shape)

scaled = StandardScaler()
test_scaled = pd.DataFrame(scaled.fit_transform(test_processed))
test_scaled
# Out:
# (312, 16)
# (78, 16)
#             0         1         2         3         4         5         6  \
# 0   -0.232840  0.137486  0.499381 -0.073501 -0.396339  4.487497  0.132604
# 1   -0.396640 -0.123541  0.289274 -0.019111 -0.379394 -0.130381  0.192145
# 2   -0.145926 -0.258009 -0.548560 -0.379446  0.209453  0.408371  0.583409
# 3    0.566100 -0.321288 -0.595250  0.348022 -0.464120 -0.746098  0.617432
# 4   -0.272954 -0.305468  0.437127  0.062474 -0.451411  0.177477  0.249559
# ..        ...       ...       ...       ...       ...       ...       ...
# 307 -0.045641 -0.091901  0.190706  0.171254 -0.411872  0.023548  0.336742
# 308 -1.763863  1.466349  0.372280 -0.440635  0.250404  0.408371 -0.369235
# 309 -0.410011  0.010928  0.359310  0.137260 -0.438702 -0.053416  0.138984
# 310  0.900384 -0.408297 -0.730134  0.715155 -0.526252 -0.746098  0.681225
# 311 -0.784409 -0.495306  0.771742 -0.495025  0.301239 -0.284310  0.264444
#
#             7         8         9        10        11        12        13  \
# 0    0.301185  0.027226 -0.261464 -0.069487  0.749278 -0.115325 -0.056705
# 1    0.371786 -0.315186 -0.261464 -0.069487 -0.029712 -0.115325 -0.056705
# 2    0.455393 -0.862157 -0.261464 -0.069487 -0.419207 -0.115325 -0.056705
# 3    0.262169 -0.066159 -0.261462 -0.069487 -0.419207 -0.115325 -0.056705
# 4    0.501841 -0.395231 -0.261464 -0.069487  0.359783 -0.115325 -0.056705
# ..        ...       ...       ...       ...       ...       ...       ...
# 307  0.273316 -0.217354 -0.261464 -0.069487  0.165036 -0.115325 -0.056705
# 308  0.780531 -0.657599 -0.261464 -0.069487 -0.419207 -0.115325 -0.056705
# 309  0.520421 -0.146203 -0.261462 -0.069487  1.528269 -0.115325 -0.056705
# 310  0.169272 -0.119522 -0.261462 -0.069487 -0.419207 -0.115325 -0.056705
# 311 -0.479145 -0.075053 -0.079272 -0.069487 -0.419207 -0.115325 -0.056705
#
#            14        15
# 0   -0.088919 -0.113297
# 1   -0.088919 -0.113297
# 2   -0.088919 -0.113297
# 3   -0.088919 -0.113297
# 4   -0.088919 -0.113297
# ..        ...       ...
# 307 -0.088919 -0.113297
# 308 -0.088919 -0.113297
# 309 -0.088919  8.538507
# 310 -0.088919 -0.113297
# 311 -0.088919 -0.113297
#
# [312 rows x 16 columns]

# %%
test1 = train_set.drop("Fe3+/Fetot", axis=1)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# 可进行中位数、众数等填充
# 可以将特征值标准化，即转化成正态分布
num_pipeline = Pipeline([
        ('imputer', SimpleImputer(missing_values=np.nan, strategy='median')), 
        ('std_scaler', StandardScaler())
    ])

major_el_processed = num_pipeline.fit_transform(test1)
major_el_processed
# Out:
# array([[-0.23284017,  0.1162558 ,  0.43766873, ..., -1.        ,
#         -0.05580917, -0.02848581],
#        [-0.39663954, -0.14692805,  0.21462613, ..., -1.        ,
#         -0.05580917, -0.02848581],
#        [-0.14592622, -0.28250761, -0.67479064, ..., -1.        ,
#         -0.05580917, -0.02848581],
#        ...,
#        [-0.41001092, -0.01134849,  0.28897366, ..., -1.        ,
#         -0.05580917,  0.52698747],
#        [ 0.90038403, -0.4340377 , -0.8675435 , ..., -1.        ,
#         -0.05580917, -0.02848581],
#        [-0.78440948, -0.24263127,  0.72679802, ..., -1.        ,
#         -0.05580917, -0.02848581]])

# %%
# 将测试集中的特征的空值设置为0
major_el_test.fillna(0, inplace=True)
# major_el_test_processed = num_pipeline.fit_transform(major_el_test)
major_el_test
# Out:
#       SiO2          TiO2         Al2O3         Cr2O3  FeOtot   MnO    MgO  \
# 9    51.04  1.000000e-02  3.600000e-01  0.000000e+00   17.75  0.79   6.88
# 42   50.69  0.000000e+00  1.000000e-07  1.000000e-07   11.25  0.00  12.17
# 33   53.79  0.000000e+00  0.000000e+00  0.000000e+00   15.06  0.00   9.74
# 311  55.52  9.760000e+00  1.300000e-01  2.000000e-02    2.72  0.07  10.56
# 272  50.64  7.100000e-01  7.160000e+00  8.300000e-01    2.77  0.07  14.65
# ..     ...           ...           ...           ...     ...   ...    ...
# 381  51.42  0.000000e+00  6.300000e-01  0.000000e+00    9.68  0.20  11.80
# 3    47.37  0.000000e+00  0.000000e+00  0.000000e+00   22.81  0.00   0.00
# 18   59.61  1.000000e-07  1.000000e-02  1.000000e-07    1.83  0.01  38.85
# 94   55.49  6.000000e-02  1.480000e+00  1.480000e+00    2.59  0.11  18.43
# 338  54.94  1.000000e-01  9.670000e+00  4.000000e-02    5.10  0.02   9.35
#
#               CaO          Na2O           K2O  P2O5   NiO           ZnO  Li2O  \
# 9    2.287000e+01  0.000000e+00  0.000000e+00   0.0  0.00  0.000000e+00   0.0
# 42   2.012000e+01  2.700000e+00  0.000000e+00   0.0  0.00  0.000000e+00   0.0
# 33   1.330000e+01  6.380000e+00  0.000000e+00   0.0  0.00  0.000000e+00   0.0
# 311  1.653000e+01  4.770000e+00  0.000000e+00   0.0  0.00  0.000000e+00   0.0
# 272  2.071000e+01  2.350000e+00  1.000000e-07   0.0  0.04  1.000000e-07   0.0
# ..            ...           ...           ...   ...   ...           ...   ...
# 381  2.327000e+01  4.300000e-01  0.000000e+00   0.0  0.00  0.000000e+00   0.0
# 3    2.212000e+01  0.000000e+00  0.000000e+00   0.0  0.00  7.610000e+00   0.0
# 18   1.000000e-07  1.000000e-07  0.000000e+00   0.0  0.00  0.000000e+00   0.0
# 94   1.945000e+01  1.380000e+00  9.000000e-02   0.0  0.06  0.000000e+00   0.0
# 338  1.510000e+01  6.030000e+00  0.000000e+00   0.0  0.00  0.000000e+00   0.0
#
#      ZrO2          V2O5
# 9     0.0  0.000000e+00
# 42    0.0  0.000000e+00
# 33    0.0  0.000000e+00
# 311   0.0  0.000000e+00
# 272   0.0  1.000000e-07
# ..    ...           ...
# 381   0.0  0.000000e+00
# 3     0.0  0.000000e+00
# 18    0.0  0.000000e+00
# 94    0.0  0.000000e+00
# 338   0.0  0.000000e+00
#
# [78 rows x 16 columns]

# %%
from sklearn.linear_model import LinearRegression

# 线性回归模型, y = a1x1 + a2x2 + ··· + a14x14 + b
lin_reg = LinearRegression()
lin_reg.fit(major_el, major_el_labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# 线性回归模型的系数
lin_reg.coef_
# Out:
# array([-4.11985553e-02, -5.66815504e-03, -1.13629046e-02,  1.45832599e-03,
#         2.04571377e-02, -2.11231213e-01,  4.47910266e-02,  3.22198257e-02,
#         1.66929125e-01, -2.50454748e-01,  6.19943558e-02,  9.56561266e-02,
#         1.11144937e-02,  4.10704353e-01, -3.87202199e-01, -1.97846310e+00])

# %%
# 线性回归模型的截距
lin_reg.intercept_
# Out:
# 0.8030765342460157

# %%
# 测试集的预测值
test_prediction = lin_reg.predict(major_el_test)
print("Prediction:", test_prediction)
# Out:
# Prediction: [-0.06257384  0.58894289  0.82488684  0.30165966  0.39406     1.07121093
#   0.24903501  0.20770954  0.29106375  0.30425776  0.39948493  0.28356756
#   0.20555357  0.3272181   0.29914064  0.16777754  0.239856    0.204059
#   0.27180087  0.07402682  0.12352209  0.24820978  0.37011707  0.28700968
#   0.22829521  0.23932608  0.26052133  0.30979713  0.2825402   1.18301761
#   0.993235    0.3372271   0.11671896  0.20029605  0.27479989  0.23964669
#   0.24786894  0.05341789  0.32286992  0.24620759  0.26170604  0.3660755
#   0.25995732  0.29954303  0.087314    0.4006292   0.20562297  0.2742204
#   0.28925168  0.2665049   0.17650619  0.24216496  0.20915131  0.0845473
#   0.78874585  0.27080565  0.28066868  0.53597757  0.18323824  1.14844462
#   0.25463152  0.34951085  0.34554113  0.21315057  0.20886274  0.264901
#   0.04172191  0.30280631  0.38631222  0.18179052  0.24748476  1.09129011
#   0.27284938  0.18333603  0.11541212  0.12257268  0.19745325  0.44124501]

# %%
# 测试集的真实值
print("Real Value:", list(major_el_test_labels))
# Out:
# Real Value: [0.0, 1.0, 1.0, 0.261, 0.15, 0.929, 0.283, 0.19, 0.34, 0.228, 0.23, 0.285, 0.212, 0.433, 0.195, 0.21, 0.302, 0.033, 0.189, 0.07, 0.0, 0.18, 0.18, 0.195, 0.249, 0.168, 0.234, 0.32, 0.229, 0.938, 0.904, 0.88, 0.282, 0.185, 0.152, 0.198, 0.32, 0.0, 0.48, 0.18, 0.19, 0.59, 0.261, 0.3, 0.219, 0.88, 0.246, 0.16, 0.219, 0.191, 0.098, 0.18, 0.254, 0.0, 0.86, 0.256, 0.388, 0.627, 0.308, 0.86, 0.227, 0.54, 0.54, 0.176, 0.2339, 0.166, 0.038, 0.88, 0.35, 0.07, 0.18, 1.0, 0.494, 0.07, 0.0, 0.0, 0.105, 0.455]

# %%
from sklearn.metrics import mean_squared_error

lin_mse = mean_squared_error(major_el_test_labels, test_prediction)
lin_rmse = np.sqrt(lin_mse) # 均方根误差
lin_rmse
# Out:
# 0.15694197802231352

# %%
from sklearn.metrics import mean_absolute_error

lin_mae = mean_absolute_error(major_el_test_labels, test_prediction) # 平均绝对误差
lin_mae
# Out:
# 0.10955822804527471

# %%
from sklearn.model_selection import cross_val_score

# 十折交叉验证来评估模型性能
scores = cross_val_score(lin_reg, major_el, major_el_labels,
                        scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    # 获得模型性能的评估，和测量评估的准确性（标准差）
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
display_scores(lin_rmse_scores)
# Out:
# Scores: [0.6038849  0.17580936 0.09340439 0.18029504 0.83611038 0.12645486
#  0.17677243 0.1983136  0.20761894 0.10406827]
# Mean: 0.27027321773333945
# Standard deviation: 0.2336502659253355

# %%
from sklearn.preprocessing import PolynomialFeatures

# 让训练集中每个特征的平方作为新的特征，获得扩展的特征集   
poly_features = PolynomialFeatures(degree=2, include_bias=False)
# major_el_poly包含原始特征并加上这个特征的平方
major_el_poly = poly_features.fit_transform(major_el)

# %%
name = poly_features.get_feature_names()
# Out:
# ['x0',
#  'x1',
#  'x2',
#  'x3',
#  'x4',
#  'x5',
#  'x6',
#  'x7',
#  'x8',
#  'x9',
#  'x10',
#  'x11',
#  'x12',
#  'x13',
#  'x14',
#  'x15',
#  'x0^2',
#  'x0 x1',
#  'x0 x2',
#  'x0 x3',
#  'x0 x4',
#  'x0 x5',
#  'x0 x6',
#  'x0 x7',
#  'x0 x8',
#  'x0 x9',
#  'x0 x10',
#  'x0 x11',
#  'x0 x12',
#  'x0 x13',
#  'x0 x14',
#  'x0 x15',
#  'x1^2',
#  'x1 x2',
#  'x1 x3',
#  'x1 x4',
#  'x1 x5',
#  'x1 x6',
#  'x1 x7',
#  'x1 x8',
#  'x1 x9',
#  'x1 x10',
#  'x1 x11',
#  'x1 x12',
#  'x1 x13',
#  'x1 x14',
#  'x1 x15',
#  'x2^2',
#  'x2 x3',
#  'x2 x4',
#  'x2 x5',
#  'x2 x6',
#  'x2 x7',
#  'x2 x8',
#  'x2 x9',
#  'x2 x10',
#  'x2 x11',
#  'x2 x12',
#  'x2 x13',
#  'x2 x14',
#  'x2 x15',
#  'x3^2',
#  'x3 x4',
#  'x3 x5',
#  'x3 x6',
#  'x3 x7',
#  'x3 x8',
#  'x3 x9',
#  'x3 x10',
#  'x3 x11',
#  'x3 x12',
#  'x3 x13',
#  'x3 x14',
#  'x3 x15',
#  'x4^2',
#  'x4 x5',
#  'x4 x6',
#  'x4 x7',
#  'x4 x8',
#  'x4 x9',
#  'x4 x10',
#  'x4 x11',
#  'x4 x12',
#  'x4 x13',
#  'x4 x14',
#  'x4 x15',
#  'x5^2',
#  'x5 x6',
#  'x5 x7',
#  'x5 x8',
#  'x5 x9',
#  'x5 x10',
#  'x5 x11',
#  'x5 x12',
#  'x5 x13',
#  'x5 x14',
#  'x5 x15',
#  'x6^2',
#  'x6 x7',
#  'x6 x8',
#  'x6 x9',
#  'x6 x10',
#  'x6 x11',
#  'x6 x12',
#  'x6 x13',
#  'x6 x14',
#  'x6 x15',
#  'x7^2',
#  'x7 x8',
#  'x7 x9',
#  'x7 x10',
#  'x7 x11',
#  'x7 x12',
#  'x7 x13',
#  'x7 x14',
#  'x7 x15',
#  'x8^2',
#  'x8 x9',
#  'x8 x10',
#  'x8 x11',
#  'x8 x12',
#  'x8 x13',
#  'x8 x14',
#  'x8 x15',
#  'x9^2',
#  'x9 x10',
#  'x9 x11',
#  'x9 x12',
#  'x9 x13',
#  'x9 x14',
#  'x9 x15',
#  'x10^2',
#  'x10 x11',
#  'x10 x12',
#  'x10 x13',
#  'x10 x14',
#  'x10 x15',
#  'x11^2',
#  'x11 x12',
#  'x11 x13',
#  'x11 x14',
#  'x11 x15',
#  'x12^2',
#  'x12 x13',
#  'x12 x14',
#  'x12 x15',
#  'x13^2',
#  'x13 x14',
#  'x13 x15',
#  'x14^2',
#  'x14 x15',
#  'x15^2']

# %%
df = pd.DataFrame(major_el_poly)
df.columns = name

# %%
df
# Out:
#         x0    x1    x2    x3    x4    x5     x6     x7    x8            x9  \
# 0    51.71  0.80  7.16  0.62  2.97  0.68  14.72  19.91  2.20  0.000000e+00
# 1    51.22  0.47  6.35  0.70  3.09  0.08  15.00  20.29  1.43  0.000000e+00
# 2    51.97  0.30  3.12  0.17  7.26  0.15  16.84  20.74  0.20  0.000000e+00
# 3    54.10  0.22  2.94  1.24  2.49  0.00  17.00  19.70  1.99  1.000000e-07
# 4    51.59  0.24  6.92  0.82  2.58  0.12  15.27  20.99  1.25  0.000000e+00
# ..     ...   ...   ...   ...   ...   ...    ...    ...   ...           ...
# 307  52.27  0.51  5.97  0.98  2.86  0.10  15.68  19.76  1.65  0.000000e+00
# 308  47.13  2.48  6.67  0.08  7.55  0.15  12.36  22.49  0.66  0.000000e+00
# 309  51.18  0.64  6.62  0.93  2.67  0.09  14.75  21.09  1.81  1.000000e-07
# 310  55.10  0.11  2.42  1.78  2.05  0.00  17.30  19.20  1.87  1.000000e-07
# 311  50.06  0.00  8.21  0.00  7.91  0.06  15.34  15.71  1.97  1.000000e-02
#
#      ...         x12^2  x12 x13  x12 x14       x12 x15  x13^2  x13 x14  \
# 0    ...  0.000000e+00      0.0      0.0  0.000000e+00    0.0      0.0
# 1    ...  0.000000e+00      0.0      0.0  0.000000e+00    0.0      0.0
# 2    ...  0.000000e+00      0.0      0.0  0.000000e+00    0.0      0.0
# 3    ...  0.000000e+00      0.0      0.0  0.000000e+00    0.0      0.0
# 4    ...  0.000000e+00      0.0      0.0  0.000000e+00    0.0      0.0
# ..   ...           ...      ...      ...           ...    ...      ...
# 307  ...  0.000000e+00      0.0      0.0  0.000000e+00    0.0      0.0
# 308  ...  0.000000e+00      0.0      0.0  0.000000e+00    0.0      0.0
# 309  ...  1.000000e-14      0.0      0.0  7.000000e-09    0.0      0.0
# 310  ...  0.000000e+00      0.0      0.0  0.000000e+00    0.0      0.0
# 311  ...  0.000000e+00      0.0      0.0  0.000000e+00    0.0      0.0
#
#      x13 x15  x14^2  x14 x15   x15^2
# 0        0.0    0.0      0.0  0.0000
# 1        0.0    0.0      0.0  0.0000
# 2        0.0    0.0      0.0  0.0000
# 3        0.0    0.0      0.0  0.0000
# 4        0.0    0.0      0.0  0.0000
# ..       ...    ...      ...     ...
# 307      0.0    0.0      0.0  0.0000
# 308      0.0    0.0      0.0  0.0000
# 309      0.0    0.0      0.0  0.0049
# 310      0.0    0.0      0.0  0.0000
# 311      0.0    0.0      0.0  0.0000
#
# [312 rows x 152 columns]

# %%
# 获得十四元二次多项式回归方程
poly_lin_reg = LinearRegression()
poly_lin_reg.fit(major_el_poly, major_el_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2dd3966b7838> in <module>
#       1 # 获得十四元二次多项式回归方程
# ----> 2 poly_lin_reg = LinearRegression()
#       3 poly_lin_reg.fit(major_el_poly, major_el_labels)
#
# NameError: name 'LinearRegression' is not defined

# %%
# 多项式回归方程的系数
poly_lin_reg.coef_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-96dd4d758758> in <module>
#       1 # 多项式回归方程的系数
# ----> 2 poly_lin_reg.coef_
#
# NameError: name 'poly_lin_reg' is not defined

# %%
# 多项式回归方程的截距
poly_lin_reg.intercept_
# Out:
# 134.65032761633884

# %%
# major_el_test_poly包含原始特征并加上这个特征的平方
major_el_test_poly = poly_features.fit_transform(major_el_test) 
# 测试集的预测值
poly_test_prediction = poly_lin_reg.predict(major_el_test_poly)
poly_test_prediction
# Out:
# array([-7.95411909,  0.28299285,  1.72302715,  0.23449132, -1.51500381,
#         0.23509946,  1.03271469,  0.28452313,  0.11434431,  0.04751912,
#         0.26021676,  0.06325925,  0.01872355,  0.25578703,  0.69142223,
#         0.309938  ,  0.28358465,  0.17415955,  0.42222221,  0.19908379,
#         0.25281669,  0.30850403,  0.23390926,  0.20296687,  0.23090414,
#         0.25220251,  0.10685632,  0.16698356,  0.41689139,  0.07579171,
#         0.26116244,  0.10044755,  0.07894324,  0.02375057])

# %%
# 测试集的真实值
np.array((major_el_test_labels))
# Out:
# array([1.   , 0.254, 0.048, 0.249, 0.096, 0.033, 0.159, 0.25 , 0.23 ,
#        0.109, 0.257, 0.085, 0.036, 0.26 , 0.145, 0.098, 0.308, 0.19 ,
#        0.414, 0.145, 0.241, 0.203, 0.22 , 0.203, 0.286, 0.281, 0.228,
#        0.263, 0.434, 0.105, 0.318, 0.154, 0.15 , 0.048])

# %%
poly_lin_mse = mean_squared_error(major_el_test_labels, poly_test_prediction)
poly_lin_rmse = np.sqrt(poly_lin_mse) # 均方根误差
poly_lin_rmse
# Out:
# 1.5978032500054644

# %%
poly_lin_mae = mean_absolute_error(major_el_test_labels, poly_test_prediction) # 平均绝对误差
poly_lin_mae
# Out:
# 0.44596541443353527

# %%
# 十折交叉验证来评估模型性能
scores = cross_val_score(poly_lin_reg, major_el_poly, major_el_labels,
                        scoring="neg_mean_squared_error", cv=10)
poly_lin_rmse_scores = np.sqrt(-scores)

# %%
display_scores(poly_lin_rmse_scores)
# Out:
# Scores: [2.5729656  0.69936983 2.73928289 0.12576574 4.1014926  0.30666221
#  2.38903287 0.97941329 0.76806795 0.41656104]
# Mean: 1.5098614015686513
# Standard deviation: 1.2719436512293247

# %%
from sklearn.linear_model import ElasticNet

# 用弹性网络对多项式回归进行正则化，它的正则项相当于Ridge回归和Lasso回归正则项的简单混合
elastic_net = ElasticNet(alpha=0.3, l1_ratio=0.3, max_iter=100000, tol=0.0005)
elastic_net.fit(major_el_poly, major_el_labels)
# Out:
# ElasticNet(alpha=0.3, copy_X=True, fit_intercept=True, l1_ratio=0.3,
#            max_iter=100000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0005, warm_start=False)

# %%
# 经过正则化后的多项式回归方程系数
elastic_net.coef_
# Out:
# array([-0.00000000e+00,  0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00,  8.23303198e-06,  9.18871213e-04,
#        -1.48664523e-04,  4.82698473e-06, -7.51494039e-05, -0.00000000e+00,
#        -1.60810258e-04, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -3.92581383e-04,  1.28635420e-03,
#         0.00000000e+00,  0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -1.34268555e-03,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -5.35090293e-04, -0.00000000e+00,  2.78923468e-04, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -5.23351855e-04,
#        -1.55635044e-04,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         1.10164915e-03, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00])

# %%
# 经过正则化后的多项式回归方程截距
elastic_net.intercept_
# Out:
# 0.5168438607405975

# %%
# 经正则化的多项式回归模型的预测值
elastic_net_prediction = elastic_net.predict(major_el_test_poly)
elastic_net_prediction
# Out:
# array([0.90529683, 0.26056124, 0.0427279 , 0.22989763, 0.2621926 ,
#        0.14965157, 0.37355884, 0.30795607, 0.23176848, 0.16999548,
#        0.24877209, 0.13753308, 0.05689957, 0.30792663, 0.27130964,
#        0.0927407 , 0.17257678, 0.18043594, 0.3577465 , 0.19358201,
#        0.24462355, 0.27640514, 0.21863456, 0.24156826, 0.24208706,
#        0.225071  , 0.27558773, 0.24024075, 0.36454911, 0.15893764,
#        0.2339136 , 0.17300358, 0.19938596, 0.01109995])

# %%
# 测试集的真实值
np.array(major_el_test_labels)
# Out:
# array([1.   , 0.254, 0.048, 0.249, 0.096, 0.033, 0.159, 0.25 , 0.23 ,
#        0.109, 0.257, 0.085, 0.036, 0.26 , 0.145, 0.098, 0.308, 0.19 ,
#        0.414, 0.145, 0.241, 0.203, 0.22 , 0.203, 0.286, 0.281, 0.228,
#        0.263, 0.434, 0.105, 0.318, 0.154, 0.15 , 0.048])

# %%
elastic_net_lin_mse = mean_squared_error(major_el_test_labels, elastic_net_prediction)
elastic_net_lin_rmse = np.sqrt(poly_lin_mse) # 均方根误差
elastic_net_lin_rmse
# Out:
# 1.5978032500054644

# %%
elastic_net_lin_mae = mean_absolute_error(major_el_test_labels, elastic_net_prediction) # 平均绝对误差
elastic_net_lin_mae
# Out:
# 0.054548726268603444

# %%
# 十折交叉验证来评估模型性能
scores = cross_val_score(elastic_net, major_el_poly, major_el_labels,
                        scoring="neg_mean_squared_error", cv=10)
elastic_net_rmse_scores = np.sqrt(-scores)

# %%
display_scores(elastic_net_rmse_scores)
# Out:
# Scores: [0.1188356  0.0633183  0.05567987 0.06521656 0.08401259 0.08634726
#  0.10780987 0.10022234 0.11877621 0.07326954]
# Mean: 0.08734881527725635
# Standard deviation: 0.022009236718624432

# %%
def plot_learning_curves(model, X_train, y_train, X_test, y_test):
    """
    画学习曲线

    model: 模型
    X_train，y_train: 训练集
    X_test, y_test：测试集
    """
    train_errors, test_errors = [], []
    for m in range(1, len(X_train)):
        model.fit(X_train[:m], y_train[:m])
        y_train_predict = model.predict(X_train[:m])
        y_test_predict = model.predict(X_test)
        train_errors.append(mean_squared_error(y_train_predict, y_train[:m]))
        test_errors.append(mean_squared_error(y_test_predict, y_test))
    plt.plot(np.sqrt(train_errors), "r-+", linewidth=2, label="train")
    plt.plot(np.sqrt(test_errors), "b-", linewidth=3, label="test")
    plt.legend(loc="upper right", fontsize=14)
    plt.xlabel("Training set size", fontsize=14)
    plt.ylabel("RMSE", fontsize=14)

# %%
plot_learning_curves(lin_reg, major_el, major_el_labels, major_el_test, major_el_test_labels)
save_fig("linear_learning_curves")
# Out:
# Saving figure linear_learning_curves

# %%
plot_learning_curves(poly_lin_reg, major_el_poly, major_el_labels, major_el_test_poly, major_el_test_labels)
plt.axis([0, 140, 0, 10])
save_fig("polynomial_learning_curves")
# Out:
# Saving figure polynomial_learning_curves

# %%
plot_learning_curves(elastic_net, major_el_poly, major_el_labels, major_el_test_poly, major_el_test_labels)
save_fig("regularized_polynomial_learning_curves")
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   positive)
# Saving figure regularized_polynomial_learning_curves
